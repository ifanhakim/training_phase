# %%
from openai import OpenAI
import os
from dotenv import load_dotenv

# %%
load_dotenv()

client = OpenAI(
    api_key=os.getenv("OPENROUTER_API_KEY"),
    base_url=os.getenv("OPENROUTER_BASE_URL"),
)

# %%
response = client.chat.completions.create(
    model="inclusionai/ling-3.0-flash-sante:free",
    messages=[
        {"role": "system", "content": "You are a helpful assistant. Answer concisely, think step-by-step."},
        {"role": "user", "content": "Hello! How can I use the OpenRouter API with Python?"},
    ],
    temperature=0.0,
    max_tokens=5000,
)

message = response.choices[0].message.content
print(message)
# Out:
# Using the OpenRouter API with Python is very straightforward because OpenRouter is fully compatible with the OpenAI API format. This means you can use the official `openai` Python SDK, which is the easiest and most common method.
#
# Here are the two best ways to do it:
#
# ### Method 1: Using the OpenAI Python SDK (Recommended)
#
# 1. **Install the SDK:**
#    ```bash
#    pip install openai
#    ```
#
# 2. **Python Code:**
#    ```python
#    from openai import OpenAI
#    import os
#
#    # Initialize the client
#    client = OpenAI(
#        base_url="https://openrouter.ai/api/v1",
#        api_key=os.getenv("OPENROUTER_API_KEY"), # Never hardcode your key!
#    )
#
#    # Make a request
#    completion = client.chat.completions.create(
#        model="openai/gpt-4o", # Use the exact model name from OpenRouter
#        messages=[
#            {"role": "user", "content": "Hello! How does OpenRouter work?"}
#        ]
#    )
#
#    print(completion.choices[0].message.content)
#    ```
#
# ### Method 2: Using the `requests` library (Raw HTTP)
#
# If you prefer not to use the OpenAI SDK, you can make standard HTTP requests.
#
# 1. **Install requests:**
#    ```bash
#    pip install requests
#    ```
#
# 2. **Python Code:**
#    ```python
#    import requests
#    import os
#
#    url = "https://openrouter.ai/api/v1/chat/completions"
#    headers = {
#        "Authorization": f"Bearer {os.getenv('OPENROUTER_API_KEY')}",
#        "Content-Type": "application/json",
#        # OpenRouter requires these two headers for usage tracking:
#        "HTTP-Referer": "https://yourwebsite.com",
#        "X-Title": "My Python App"
#    }
#    data = {
#        "model": "openai/gpt-4o",
#        "messages": [
#            {"role": "user", "content": "Hello!"}
#        ]
#    }
#
#    response = requests.post(url, headers=headers, json=data)
#    print(response.json())
#    ```
#
# ### Important Tips for OpenRouter:
# 1. **Model Names:** You must use the exact model identifier provided by OpenRouter (e.g., `openai/gpt-4o`, `anthropic/claude-3-opus`, `meta-llama/llama-3-70b`). You can find the list in their [models directory](https://openrouter.ai/models).
# 2. **API Key:** Get your key from [OpenRouter's dashboard](https://openrouter.ai/keys). Store it in an environment variable (`OPENROUTER_API_KEY`) rather than pasting it directly into your code.
# 3. **Pricing/Context:** OpenRouter routes your request to different providers. Check the model page for context limits and pricing before coding.
